# %% [markdown]
# <a href="https://colab.research.google.com/github/Ladouce07/Data-Science/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Course: Data Science for Decision Support**
#
# **Author:** July Ladouce Nuessi, NKADJI
#
# **Author 2:** Achille, Monthe Djeuthie
#
#
# ---

# %% [markdown]
# # Problem: **Classification** (Total score 34)

# %% [markdown]
# # **`Task 1 „Data Pre-processing“ (7 Scores)`**

# %% [markdown]
# 1)	Read the data from your individual variant into Python notebook

# %%
#Write your code here
import pandas as pd

df = pd.read_csv("water_potability.csv")

df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
#add more cell if needed to each code cell

# %% [markdown]
# 2) Output the main information (number of variables, number of instances).

# %%
#Write your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# *Comment the results of the previous program*

# %% [markdown]
# 3) Output some first rows of the dataset.

# %%
#Write your code here
df.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %% [markdown]
# 4) Make explanatory data analyses for each variable (mean, std, etc.).

# %% [markdown]
# 5) Look at independent and dependent variables. Divide the dataset accordingly into matrices X and Y. Output the shapes of these matrices.

# %% [markdown]
# *Comment the results of the previous program*

# %% [markdown]
# 6) Look at data types of the variables. Are there any categorical variable you need to encode? Execute necessary transformations. Drop some columns if necessary, when recommended in your individual variant.

# %% [markdown]
# 7) Are there any Nan values? Try different filling of them (mean, median).

# %%
#Write your code here

df = df.apply(lambda x: x.fillna (x.mean ()),axis=0)
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# *Comment the results of the previous program*

# %%
#Write your code here

X = df.drop(['Potability'], axis=1)
Y = df['Potability']
print(X.shape)
print(Y.shape)
X.isna().sum()
# Out:
# (3276, 9)
# (3276,)
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# # **`Task 2 “Data Analysis” (10 Scores)`**

# %% [markdown]
# Compare 4 ML methods:
#
# *   Random Forest classifier
# *   XGBoost classifier
# *   CatBoost classifier
# *   Light GBM classifier

# %% [markdown]
# 1) Scale your whole dataset. Try different scalings for your dataset. (Standard Scaler, MinMax Scaler). Experiment with Standard Scaler first.

# %%
#Write your code here.
from sklearn import preprocessing
sc_standard = preprocessing.StandardScaler().fit(X)
XS_scaler = sc_standard.transform(X)

# %% [markdown]
# 2) Divide your dataset into 2 parts: training set and testing set (80:20). Use defined random_state to reproduce the splitting for other Scaler. Output the dimension of the resulting datasets.

# %%
#Write your code here
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(XS_scaler, Y, test_size = 0.20, random_state=0)

print("dimension of x_train", x_train.shape)
print("dimension of y_train", y_train.shape)
print("dimension of x_test", x_test.shape)
print("dimension of y_test", y_test.shape)
# Out:
# dimension of x_train (2620, 9)
# dimension of y_train (2620,)
# dimension of x_test (656, 9)
# dimension of y_test (656,)

# %% [markdown]
# 3) **Preliminary analysis:** Build 4 models based on 4 mentioned ML methods. For each model: train with training set and output the confusion matrix and accuracy of the model using training set. Test your models with the testset and output the confusion matrix and accuracy of the testset. Compare the same performance metrics calculated inside one model for training and testing sets. Find optimal parameters with GridSearchCV() function for each of the models for the whole dataset.

# %% [markdown]
# **Random Forest classifier**

# %%
#Write your code here
from sklearn.metrics import accuracy_score as accs
from sklearn.metrics import confusion_matrix as conf
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

#fitting of the model
rf = RandomForestClassifier()
rf.fit(x_train, y_train)


# prediction of values with training and testing set
yTrainPred = rf.predict(x_train)
yTestPred = rf.predict(x_test)


#using training set

accu = accs(y_train,yTrainPred)
mat = conf(y_train,yTrainPred)

# using testing set

accu1 = accs(y_test,yTestPred)
mat1 = conf(y_test,yTestPred)

# output with trainig and testing set

print("+++++ Using training set we have these response : ")
print("Accuracy :", accu)
print("Confusion Matrix :", mat)
print("+++++ Using testing set we have these response : ")
print("Accuracy :", accu1)
print("Confusion Matrix :", mat1)
# Out:
# +++++ Using training set we have these response :
# Accuracy : 1.0
# Confusion Matrix : [[1586    0]
#  [   0 1034]]
# +++++ Using testing set we have these response :
# Accuracy : 0.6844512195121951
# Confusion Matrix : [[368  44]
#  [163  81]]

# %% [markdown]
# *Comment the results of the previous program*. *Compare the results of the same characteristics for training and test sets. Make conclusions.*
#
# What we can say about random forest classifier is that, this model give the perfect result either in accuracy other confusion matrix.

# %% [markdown]
# **XGBoost classifier**

# %%
#Write your code here
import xgboost as xgb


model1 = xgb.XGBClassifier()
model1.fit(x_train, y_train)
yTrainPred = model1.predict(x_train)
yTestPred = model1.predict(x_test)


#using training set

accud = accs(y_train,yTrainPred)
matd = conf(y_train,yTrainPred)

# using testing set

accud1 = accs(y_test,yTestPred)
matd1 = conf(y_test,yTestPred)

# output with trainig and testing set

print("+++++ Using training set we have these response : ")
print("Accuracy :", accud)
print("Confusion Matrix :", matd)
print("+++++ Using testing set we have these response : ")
print("Accuracy :", accud1)
print("Confusion Matrix :", matd1)
# Out:
# +++++ Using training set we have these response :
# Accuracy : 0.9958015267175573
# Confusion Matrix : [[1586    0]
#  [  11 1023]]
# +++++ Using testing set we have these response :
# Accuracy : 0.649390243902439
# Confusion Matrix : [[325  87]
#  [143 101]]

# %% [markdown]
# *Comment the results of the previous program*. *Compare the results of the same characteristics for training and test sets. Make conclusions.*
#
#
# About XGBoost classifier this give the perfect result on Accuracy

# %%
pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 10.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **CatBoost classifier**

# %%
#Write your code here
from catboost import CatBoostClassifier

cb= CatBoostClassifier()
cb.fit(x_train, y_train)
yTrainPred = cb.predict(x_train)
yTestPred = cb.predict(x_test)



#using training set

accuk = accs(y_train,yTrainPred)
matk = conf(y_train,yTrainPred)

# using testing set

accuk1 = accs(y_test,yTestPred)
matk1 = conf(y_test,yTestPred)

# output with trainig and testing set

print("+++++ Using training set we have these response : ")
print("Accuracy :", accuk)
print("Confusion Matrix :", matk)
print("+++++ Using testing set we have these response : ")
print("Accuracy :", accuk1)
print("Confusion Matrix :", matk1)
# Out:
# Learning rate set to 0.015543
# 0:	learn: 0.6406239	total: 48.8ms	remaining: 48.7s
# 1:	learn: 0.5986546	total: 52.6ms	remaining: 26.3s
# 2:	learn: 0.5608848	total: 55.7ms	remaining: 18.5s
# 3:	learn: 0.5223049	total: 58.2ms	remaining: 14.5s
# 4:	learn: 0.4897986	total: 61.4ms	remaining: 12.2s
# 5:	learn: 0.4593338	total: 64.6ms	remaining: 10.7s
# 6:	learn: 0.4202607	total: 65.8ms	remaining: 9.33s
# 7:	learn: 0.3900988	total: 68.1ms	remaining: 8.45s
# 8:	learn: 0.3654140	total: 71.2ms	remaining: 7.84s
# 9:	learn: 0.3361655	total: 72.7ms	remaining: 7.2s
# 10:	learn: 0.3166494	total: 75.9ms	remaining: 6.82s
# 11:	learn: 0.2948197	total: 79.4ms	remaining: 6.54s
# 12:	learn: 0.2752220	total: 82.6ms	remaining: 6.27s
# 13:	learn: 0.2603131	total: 86.3ms	remaining: 6.08s
# 14:	learn: 0.2411598	total: 88.1ms	remaining: 5.79s
# 15:	learn: 0.2249015	total: 91.3ms	remaining: 5.61s
# 16:	learn: 0.2075709	total: 92.8ms	remaining: 5.37s
# 17:	learn: 0.1973924	total: 96.1ms	remaining: 5.24s
# ...

# %% [markdown]
# *Comment the results of the previous program*. *Compare the results of the same characteristics for training and test sets. Make conclusions.*
#
#
# Either with training set or testing set the result give by the Catboost model is perfect.

# %% [markdown]
# **Light GBM classifier**

# %%
#Write your code here
from lightgbm import LGBMClassifier

lg= LGBMClassifier()
lg.fit(x_train, y_train)
yTrainPred = lg.predict(x_train)
yTestPred = lg.predict(x_test)

#using training set

accus = accs(y_train,yTrainPred)
mats = conf(y_train,yTrainPred)

# using testing set

accus1 = accs(y_test,yTestPred)
mats1 = conf(y_test,yTestPred)

# output with trainig and testing set

print("+++++ Using training set we have these response : ")
print("Accuracy :", accus)
print("Confusion Matrix :", mats)
print("+++++ Using testing set we have these response : ")
print("Accuracy :", accus1)
print("Confusion Matrix :", mats1)
# Out:
# +++++ Using training set we have these response :
# Accuracy : 1.0
# Confusion Matrix : [[1586    0]
#  [   0 1034]]
# +++++ Using testing set we have these response :
# Accuracy : 1.0
# Confusion Matrix : [[412   0]
#  [  0 244]]

# %% [markdown]
# *Comment the results of the previous program*. *Compare the results of the same characteristics for training and test sets. Make conclusions.*
#
#
# With light GBM classifier we can see that result is still perfect giving for the both sets

# %%
#Write your code here
data = {'model':['Random Forest classifier', 'XGBoost classifier', 'CatBoost classifier','Light GBM classifier'],
        'Accuracy Training set':[accu, accud, accuk, accus], 'Accuracy Testing set':[accu1, accud1, accuk1, accus1]}

df_ = pd.DataFrame(data)
df_
# Out:
#                       model  Accuracy Training set  Accuracy Testing set
# 0  Random Forest classifier                    1.0                   1.0
# 1        XGBoost classifier                    1.0                   1.0
# 2       CatBoost classifier                    1.0                   1.0
# 3      Light GBM classifier                    1.0                   1.0

# %%
df2 = pd.DataFrame(columns=['real Values', 'Random Forest classifier model',
                            'XGBoost classifier model', 'CatBoost classifier model', 'Light GBM classifier Model'])

df2['real Values'] = y_test
df2['Random Forest classifier model'] = rf.predict(x_test)
df2['XGBoost classifier model'] = model1.predict(x_test)
df2['CatBoost classifier model']=cb.predict(x_test)
df2['Light GBM classifier Model']=lg.predict(x_test)

df2
# Out:
#       real Values  Random Forest classifier model  XGBoost classifier model  \
# 2017            1                               1                         1
# 2533            0                               0                         0
# 589             0                               0                         0
# 482             0                               0                         0
# 2620            0                               0                         0
# ...           ...                             ...                       ...
# 2802            1                               1                         1
# 1120            1                               1                         1
# 601             0                               0                         0
# 2381            1                               1                         1
# 98              0                               0                         0
#
# ...

# %% [markdown]
# # **`Task 4 “K-fold cross validation” (7 Scores)`**

# %% [markdown]
# 1) Use the functions cross_val_score() or cross_validation() and make 5-fold cross validation. Use the best hyperparameter values for each model found in task 2. Use the whole dataset.

# %% [markdown]
# **Best Parameters for random Forest Classifier model**

# %%
#Write your code here for Random Forest Classifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

#define the parameters
param_distributions={'bootstrap': [True, False],
                     'n_estimators': [25, 50, 100, 150],
                      'max_features': ['sqrt', 'log2', None],
                      'max_depth': [3, 6, 9],
                      'max_leaf_nodes': [3, 6, 9],}

#performe the gridsearchCV
grid_search_random = GridSearchCV(rf,param_distributions)
grid_search_random.fit(x_train, y_train)

print("Best parameters:", grid_search_random.best_params_)
# Out:
# Best parameters: {'bootstrap': True, 'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 3, 'n_estimators': 25}

# %%
rf=RandomForestClassifier(bootstrap= True, max_depth= 3, max_features= 'sqrt', max_leaf_nodes= 3, n_estimators= 25)
rfScores = cross_val_score(rf, X, Y, scoring='accuracy',cv=5)
rfScores.mean()
# Out:
# 0.6104994414447962

# %% [markdown]
# **Best Parameters for XGBoost Classifier model**

# %%
#define the parameters
param_grid_xg = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 500, 1000],
    'subsample': [0.8, 1.0],
}
#performe the gridsearchCV
grid_search_XG = GridSearchCV(model1, param_grid_xg, cv=5)
grid_search_XG.fit(x_train, y_train)

#print the best parameters
print("Best parameters",grid_search_XG.best_params_)
# Out:
# Best parameters {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
#Write your code here for XG Boost Classifier
model1=xgb.XGBClassifier(learning_rate= 0.1, max_depth= 3, n_estimators= 100, subsample= 0.8)
modelScore = cross_val_score(model1, X,Y, scoring='accuracy',cv=5)
modelScore.mean()
# Out:
# 0.625157791845094

# %% [markdown]
# **Best parameters for CatBoost Classifier**

# %%
#define the parameters
param_grid_cb = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.1, 1],
    'iterations': [100, 200, 300]
}

#performe the gridsearchCV
grid_search_CB = GridSearchCV(cb, param_grid_cb, cv=3, scoring='accuracy')
grid_search_CB.fit(x_train, y_train)

#print the best parameters
print("Best parameters",grid_search_CB.best_params_)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1:	learn: 0.5460837	total: 10.1ms	remaining: 494ms
# 2:	learn: 0.4874564	total: 14.8ms	remaining: 480ms
# 3:	learn: 0.4469642	total: 23ms	remaining: 553ms
# 4:	learn: 0.3948525	total: 24.2ms	remaining: 460ms
# 5:	learn: 0.3494589	total: 25.1ms	remaining: 393ms
# 6:	learn: 0.3262592	total: 33.4ms	remaining: 444ms
# 7:	learn: 0.2997873	total: 42ms	remaining: 483ms
# 8:	learn: 0.2752311	total: 47ms	remaining: 475ms
# 9:	learn: 0.2557258	total: 55.5ms	remaining: 499ms
# 10:	learn: 0.2358028	total: 63.7ms	remaining: 515ms
# 11:	learn: 0.2180866	total: 68.8ms	remaining: 505ms
# 12:	learn: 0.1965671	total: 70.7ms	remaining: 473ms
# 13:	learn: 0.1823672	total: 79.5ms	remaining: 488ms
# 14:	learn: 0.1717900	total: 88.3ms	remaining: 500ms
# 15:	learn: 0.1586380	total: 96.9ms	remaining: 509ms
# 16:	learn: 0.1426681	total: 97.8ms	remaining: 478ms
# 17:	learn: 0.1304902	total: 103ms	remaining: 468ms
# ...

# %%
#Write your code here for Catboost Classifier
cb=CatBoostClassifier(depth= 4, iterations= 100, learning_rate= 0.01)
cbb = cross_val_score(cb, X, Y, scoring='accuracy',cv=5)
cbb.mean()
# Out:
# 0:	learn: 0.6923059	total: 1.92ms	remaining: 190ms
# 1:	learn: 0.6916482	total: 3.89ms	remaining: 191ms
# 2:	learn: 0.6910900	total: 5.49ms	remaining: 177ms
# 3:	learn: 0.6903000	total: 7.01ms	remaining: 168ms
# 4:	learn: 0.6897262	total: 8.51ms	remaining: 162ms
# 5:	learn: 0.6890030	total: 10ms	remaining: 157ms
# 6:	learn: 0.6882623	total: 11.5ms	remaining: 153ms
# 7:	learn: 0.6876133	total: 13ms	remaining: 150ms
# 8:	learn: 0.6870983	total: 14.5ms	remaining: 147ms
# 9:	learn: 0.6865431	total: 16ms	remaining: 144ms
# 10:	learn: 0.6859756	total: 17.5ms	remaining: 142ms
# 11:	learn: 0.6854589	total: 19.3ms	remaining: 142ms
# 12:	learn: 0.6849813	total: 20.9ms	remaining: 140ms
# 13:	learn: 0.6844805	total: 22.4ms	remaining: 137ms
# 14:	learn: 0.6837867	total: 23.9ms	remaining: 135ms
# 15:	learn: 0.6832220	total: 25.4ms	remaining: 133ms
# 16:	learn: 0.6826751	total: 26.9ms	remaining: 132ms
# 17:	learn: 0.6820294	total: 28.5ms	remaining: 130ms
# ...

# %% [markdown]
# **Best parameters LGBM classifier**

# %%
#define the parameters
param_grid_lg = {
                  'learning_rate': [0.01], 'n_estimators': [8, 24],
                   'num_leaves': [6, 8, 12, 16], 'boosting_type': ['gbdt'],
                   'objective': ['binary'], 'seed': [500],
                   'colsample_bytree': [0.65, 0.75, 0.8],
                   'subsample': [0.7, 0.75], 'reg_alpha': [1, 2, 6],
                   'reg_lambda': [1, 2, 6]
}

#performe the gridsearchCV
grid_search_LB = GridSearchCV(lg, param_grid_lg, cv=5)
grid_search_LB.fit(x_train, y_train)

#print the best parameters
print("Best parameters",grid_search_LB.best_params_)
# Out:
# Best parameters {'boosting_type': 'gbdt', 'colsample_bytree': 0.75, 'learning_rate': 0.01, 'n_estimators': 24, 'num_leaves': 16, 'objective': 'binary', 'reg_alpha': 1, 'reg_lambda': 1, 'seed': 500, 'subsample': 0.7}

# %%
from numpy.random import seed
#Write your code here for Light GBM Classifier
lg = LGBMClassifier(boosting_type='gbdt', colsample_bytree ='0.75', learning_rate=0.01, n_estimators=24, num_leaves=16, objective='binary', reg_alpha=1, reg_lambda=1, seed=500, subsample =0.7)
lgs = cross_val_score(lg, X,Y, scoring='accuracy',cv=5)
lgs.mean()
# Out:
# 0.609890150809905

# %% [markdown]
# 2) Make the conclusion about the best model comparing 8 previously built models
# (assignments 1-2) considering classification accuracy calculated on the testset.
#
#
#
# comparing about the 8 previosly built model considering accuracy on the testet all models are gut for this Dataset expect Support Vector Machine Classifier, where the accuracy were 1.0 but the predict values was wrong

# %%
data = {'Differents Models':['Random Forest','XG Boost','Cat Boost', 'Light GBM'],
        'Accuracy Testing set':[accu1, accud1, accuk1, accus1]}

dm = pd.DataFrame(data)

dm
# Out:
#   Differents Models  Accuracy Testing set
# 0     Random Forest                   1.0
# 1          XG Boost                   1.0
# 2         Cat Boost                   1.0
# 3         Light GBM                   1.0

# %% [markdown]
# Considering the results obtained in the first assigment, we see that all the models in the testing set have the same accuracy which is equals to 1.

# %% [markdown]
# 3) Select 3 best models for your dataset based on the accuracy metric. Plot the results of this
# metric obtained by the selected models in with Plotly Bar plo

# %%
import plotly.graph_objects as go

# considering the accuracies on the testing set
categories = ['Random Forest','XG Boost','CatBoost']
accuracies = [accu1, accud1, accuk1]

# Create bar plot
fig = go.Figure(data=go.Bar(x=categories, y=accuracies))

# Customize the plot
fig.update_layout(
    title='Accuracies of Different Models',
    xaxis_title='Models',
    yaxis_title='Accuracy',
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y_test
# Out:
# 2017    1
# 2533    0
# 589     0
# 482     0
# 2620    0
#        ..
# 2802    1
# 1120    1
# 601     0
# 2381    1
# 98      0
# Name: Potability, Length: 656, dtype: int64

# %% [markdown]
# # **Task 2: “Classification dashboard ” (30 scores) **

# %% [markdown]
# 1) Create a dashboard, in which you use 3 best models from selected in previous task. The title
# of the dashboard should include your names and surnames. Use ipywidgets library.

# %%
df.head(5)
# Out:
#                       model  Accuracy Training set  Accuracy Testing set
# 0  Random Forest classifier                    1.0                   1.0
# 1        XGBoost classifier                    1.0                   1.0
# 2       CatBoost classifier                    1.0                   1.0
# 3      Light GBM classifier                    1.0                   1.0

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def random_forest():
  randForest = rf.fit(x_train, y_train)
  return randForest

def xg_boost():
  xg1 = model1.fit(x_train, y_train)
  return xg1

def light():
  light1 = lg.fit(x_train, y_train)
  return light1

model_data = {
    'Random Forest': {
        'Train Accuracy': accu,
        'Test Accuracy': accu1,
        'Confusion Matrix': mat,
        'Hyper Parameters': param_distributions
    },
    'XGBoost': {
        'Train Accuracy': accud,
        'Test Accuracy': accud1,
        'Confusion Matrix': matd,
        'Hyper Parameters': param_grid_xg
    },
    'LightGBM': {
        'Train Accuracy': accus,
        'Test Accuracy': accus1,
        'Confusion Matrix': mats,
        'Hyper Parameters': param_grid_lg
    }
}

# Create the widgets
model = widgets.SelectMultiple(options=['Random Forest', 'XGBoost', 'LightGBM'], description='Models:')

tab=widgets.Tab()
Page1_box=widgets.Output()
Page2_box = widgets.Output()
Page3_box = widgets.Output()
tab.children=[Page1_box, Page2_box, Page3_box]
for i, title in enumerate(['Pre-processed', 'Performance', 'Forecast']):
    tab.set_title(i, title)


# Define the update function
def update_dashboard(change):
    with Page2_box:
        Page2_box.clear_output()
        # Perform actions based on the selected models
        selected_models = model.value
        for mod in selected_models:
            model_metrics = model_data[mod]
            train_accuracy = model_metrics['Train Accuracy']
            test_accuracy = model_metrics['Test Accuracy']
            confusion_matrix = model_metrics['Confusion Matrix']

            # Create a DataFrame for the confusion matrix
            cm_df = pd.DataFrame(confusion_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

            # Display the metrics table
            print(f"Performance Metrics for {mod}:")
            print(f"Train Accuracy: {train_accuracy:.2f}")
            print(f"Test Accuracy: {test_accuracy:.2f}")
            print("\nConfusion Matrix:")
            display(cm_df)
            print("---------------------------------------")

        # Create a bar chart for accuracy
        accuracy_data = [model_data[model]['Test Accuracy'] for model in selected_models]
        plt.figure(figsize=(10, 6))
        plt.bar(selected_models, accuracy_data)
        plt.xlabel('Models')
        plt.ylabel('Accuracy')
        plt.title('Accuracy Metrics')
        plt.show()

    with Page1_box:
      Page1_box.clear_output()
      selected_models = model.value
      for mod in selected_models:
            model_metrics = model_data[mod]
            parameters = model_metrics['Hyper Parameters']

            # Display the metrics table
            print(df.head())
            print(f"hypers parameters for {mod}:")
            print(f"Parameters: {parameters}")
            print("---------------------------------------")
    with Page3_box:
      Page3_box.clear_output()
      selected_models = model.value
      results_df = pd.DataFrame(columns=['True Value'])
# Train and obtain predictions for each selected model
      for mod in selected_models:
        if mod == 'Random Forest':
          selectModel = random_forest()
        elif mod == 'XGBoost':
          selectModel =xg_boost()
        else:
          selectModel = light()



      y_pred = selectModel.predict(x_test)
      results_df[mod] = y_pred

# Add the true values to the DataFrame
      results_df['True Value'] = y_test

# Print the resulting DataFrame
      print(results_df)
      print("---------------------------------------")

# Register the update function with the dropdown
model.observe(update_dashboard, 'value')

# Create the dashboard layout
dashboard = widgets.HBox([model])

# Display the dashboard
display(widgets.HTML('<br><b><center><font size="5"> Achille Monthe Djeuthie(533896) and July Ladouce Nuessi NKADJI (600978)</font></center></b>'))
display(dashboard)
display(tab)
# Out:
# HTML(value='<br><b><center><font size="5"> Achille Monthe Djeuthie(533896) and July Ladouce Nuessi NKADJI (600…
# ...

# %% [markdown]
# *!! Comment the obtained results here !!*

# %% [markdown]
# 2) Compare the accuracy results of Task 3 (average accuracy) and Task 4. Make conclusions about the best model and corresponding machine learning method.

# %% [markdown]
# *!! Comment the obtained results here !!*
